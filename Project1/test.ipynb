# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:password@127.0.0.1/sparkifydb
# Out:
# 'Connected: postgres@sparkifydb'

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, Decimal('233.40363'))]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', Decimal('NaN'), Decimal('NaN'))]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 10, 20, 33, 56, 796000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 2, 11, 45, 11, 2018, 6),
#  (datetime.datetime(2018, 11, 10, 20, 36, 10, 796000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 2, 11, 45, 11, 2018, 6),
#  (datetime.datetime(2018, 11, 10, 20, 40, 34, 796000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 2, 11, 45, 11, 2018, 6),
#  (datetime.datetime(2018, 11, 10, 22, 36, 13, 796000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 4, 11, 45, 11, 2018, 6),
#  (datetime.datetime(2018, 11, 10, 22, 36, 46, 796000, tzinfo=psycopg2.tz.FixedOffsetTimezone(offset=0, name=None)), 4, 11, 45, 11, 2018, 6)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
